# %%
import pandas as pd
df = pd.read_csv("Advertising.csv")
print(df)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
x=df[['Newspaper']]
x
# Out:
#      Newspaper
# 0         69.2
# 1         45.1
# 2         69.3
# 3         58.5
# 4         58.4
# ..         ...
# 195       13.8
# 196        8.1
# 197        6.4
# 198       66.2
# 199        8.7
#
# [200 rows x 1 columns]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
import seaborn as sns
sns.regplot(x="Newspaper", y="Sales", data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([15.47167765, 15.47167765, 14.89203768, 15.01155108, 12.50176977,
#        15.45972631, 13.93593052, 13.41007158, 13.09336108, 14.19288432,
#        12.44201307, 14.08532226, 17.37791631, 12.87226129, 13.9000765 ,
#        14.4139841 , 14.78447563, 13.15909344, 14.25264102, 12.96787201,
#        16.74449532, 19.12281189, 13.02165304, 16.63095759, 12.36432936,
#        13.58934167, 14.33032472, 12.92006665, 13.85824681, 12.4360374 ,
#        13.57739033, 13.40409591, 15.89595021, 17.65279712, 14.52154616,
#        12.62725883, 12.81848027, 15.8780232 , 12.6332345 , 13.54751198])

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test, y_pred)  # MAE
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 4.782194119516899

# %%
import numpy as np
rsme =np.sqrt(mse)  # RMSE
print("Root Mean Squared Error:", rsme)
# Out:
# Root Mean Squared Error: 5.533600454969853
