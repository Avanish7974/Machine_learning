# %% [markdown]
# # REGGREATION :
# 1:LINER REGGREATION (libary skylearon ,modelfit ,model predict)

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df={'Country': ['India', 'USA', 'China', 'Japan','Germany'],
     'GDP': [12240,27195,37675,50960,55805],
     'Life': [4.5,5.8,6.5,7.3,7.2]}

df = pd.DataFrame(df)
print(df)
# Out:
#    Country    GDP  Life
# 0    India  12240   4.5
# 1      USA  27195   5.8
# 2    China  37675   6.5
# 3    Japan  50960   7.3
# 4  Germany  55805   7.2

# %%
import seaborn as sns
sns.scatterplot(x="GDP", y="Life", data=df)
# Out:
# <Axes: xlabel='GDP', ylabel='Life'>

# %%
sns.regplot(x="GDP", y="Life", data=df)
# Out:
# <Axes: xlabel='GDP', ylabel='Life'>

# %%
model= LinearRegression()

# %%
# Convert df dictionary to a pandas DataFrame
df = pd.DataFrame(df)

model.fit(df[['GDP']], df['Life'])
# Out:
# LinearRegression()

# %%
model.predict([[20187]])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.19917367])

# %%
model.intercept_
# Out:
# np.float64(3.9081861448106983)

# %%
model.coef_             # y = mx + c (coef if m and intercept is c)
# Out:
# array([6.39514305e-05])

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\AVANISH SINGH\OneDrive\Desktop\Advertising.csv")
print(df)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
x=df[['TV']]
x
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
x11 = [['TV'],['Radio'],['Newspaper']]

# %%
y=df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
import seaborn as sns
sns.regplot(x="TV", y="Sales", data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=42) #  ramdom number me  vo value jis s vahi data milenga
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2, random_state=42) #  ramdom number me  vo value jis s vahi data milenga
#
# File c:\Users\AVANISH SINGH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([14.71794394, 16.2115484 , 20.74819743,  7.66403631, 17.37013877,
#        10.61402143, 17.2072847 ,  9.44612512, 17.46785121, 15.2669948 ,
#         8.58532504,  9.73460946, 18.03086098,  7.37089899, 13.61053628,
#        15.03899911,  7.45930549, 16.31391381, 10.62332738, 18.16579721,
#        17.79821232, 10.27435438,  8.88776831, 18.79394862, 10.33019006,
#         9.60897918, 17.05373658, 13.60123034, 11.17703121,  7.51048819,
#        16.41627922, 10.339496  , 16.37440246,  7.90599093, 20.18053468,
#        18.203021  ,  9.36702457, 19.85482655, 12.57292322,  8.39920611])

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %% [markdown]
# # Error

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)        # MSE
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 10.204654118800956

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test, y_pred)  # MAE
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 2.444420003751042

# %% [markdown]
# from sklearn.metrics import mean_absolute_error
# mae=mean_absolute_error(y_test, y_pred)  # MAE
# print("Mean Absolute Error:", mae)
