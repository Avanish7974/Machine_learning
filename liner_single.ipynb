# %% [markdown]
# ## Linear Regression Single Variable

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = {'Name' : ['Hunngary','korea','France','Australia','US'],
        'Age' : [25,30,35,40,45],
        'Premium':[18000,32000,42000,47000,55000]
        }
df = pd.DataFrame(data)

# %%
import seaborn as sns
sns.scatterplot(x='Age',y='Premium',data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Premium'>

# %% [markdown]
# ### Best Fit Line Or Regression Line
#
# m = Coefficient/Slope/Gradient
# c = intercept

# %%
sns.regplot(x = X,y = y,data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Premium'>

# %%
X = df[['Age']]
y = df['Premium']

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
df
# Out:
#         Name  Age  Premium
# 0   Hunngary   25    18000
# 1      korea   30    32000
# 2     France   35    42000
# 3  Australia   40    47000
# 4         US   45    55000

# %%
model.coef_
# Out:
# array([1780.])

# %%
model.intercept_
# Out:
# np.float64(-23500.0)

# %%
model.predict([[50]])
# Out:
# c:\Users\AVANISH SINGH\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65500.])
